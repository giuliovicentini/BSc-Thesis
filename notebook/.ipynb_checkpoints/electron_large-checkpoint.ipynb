# %%
# %matplotlib inline
import pandas as pd
import uproot
import matplotlib.pyplot as plt
import numpy as np
import healpy as hp

# %%
datafile = uproot.open("/mnt/Storage/gvicentini/ElectronDataset/Hits/eminus_hits_dn_0.root")

# %%
trueINFO = datafile["true_info"]
trueINFO_pd = trueINFO.pandas.df()
trueINFO_pd
# Out:
#        evtID         E             x             y             z             R
# entry
# 0          0  4.747791   8290.779297  11995.618164    911.742859  14610.377930
# 1          1  3.566943  10731.096680 -10665.593750   8294.514648  17254.283203
# 2          2  0.525494  -8256.232422  -3160.362549   2119.616943   9090.986328
# 3          3  8.883169   3101.022949 -11927.612305  -7299.741699  14323.773438
# 4          4  4.359181   3229.798584  -7398.088867  -8300.032227  11578.163086
# ...      ...       ...           ...           ...           ...           ...
# 99995  99995  4.337835   6755.354492   3033.865723  12181.961914  14256.204102
# 99996  99996  3.728539  -3448.209229  11290.456055  11033.193359  16158.461914
# 99997  99997  5.171671   -581.555176 -11477.789062 -10039.052734  15259.764648
# 99998  99998  9.444701  -8513.088867  -8359.314453   4682.304199  12816.972656
# 99999  99999  5.478669   1984.813599   4117.785645  -1478.999512   4804.485840
#
# [100000 rows x 6 columns]

# %%
def filt_pos(frame):

    data = []
    for i in range(0,len(frame)):
        if frame.loc[i, 'R'] < 16500 and frame.loc[i, 'R'] > 15500:
                data.append({'evtID': frame.loc[i, 'evtID'], 'E': frame.loc[i, 'E'],
                           'x': frame.loc[i, 'x'],
                           'y': frame.loc[i, 'y'],
                           'z': frame.loc[i, 'z'],
                           'R': frame.loc[i, 'R']})
            
    trueINFO_pd_0 = pd.DataFrame(data)
    return trueINFO_pd_0

# %%
infoR = filt_pos(trueINFO_pd)
infoR
# Out:
#        evtID          E             x             y             z  \
# 0         15   2.138439 -10265.950195  12398.058594    520.106934
# 1         24   7.528636   9267.583008  11250.204102   5964.791016
# 2         39   9.109471  10031.009766  -3116.898438  12555.167969
# 3         45   6.822966  -5631.937500 -10263.833984  11184.304688
# 4         47   8.632144   2326.902344 -11795.177734  10841.166992
# ...      ...        ...           ...           ...           ...
# 13787  99982   1.524385   3524.559814   3046.181641  15070.577148
# 13788  99985   8.282839   3325.694092 -15144.327148   2343.557129
# 13789  99987   1.522730   4802.004883  14820.054688   2337.423584
# 13790  99990  10.493291  11531.410156  10224.990234   2577.600342
# 13791  99996   3.728539  -3448.209229  11290.456055  11033.193359
#
#                   R
# 0      16105.034180
# 1      15749.092773
# 2      16369.742188
# 3      16191.160156
# 4      16188.625977
# ...             ...
# 13787  15774.157227
# 13788  15681.298828
# 13789  15752.994141
# 13790  15625.871094
# 13791  16158.461914
#
# [13792 rows x 6 columns]

# %%
energyR = infoR.loc[:, 'E']
plt.hist(energyR, bins=20, ec='black', color='green')
plt.show()

# %%
def filt_en(frame):

    data = []
    for i in range(0,len(frame)):
        if frame.loc[i, 'E'] < 6.01 and frame.loc[i, 'E'] > 5.99:
                data.append({'evtID': frame.loc[i, 'evtID'], 'E': frame.loc[i, 'E'],
                           'x': frame.loc[i, 'x'],
# 3          9391  17100  394.266968  False
# 4          9391  14771   29.709875  False
# ...         ...    ...         ...    ...
# 9386       9391  17669  727.346252   True
# 9387       9391  17678  174.832062   True
# 9388       9391  17705  101.349831   True
# 9389       9391  17717  145.121109   True
# 9390       9391  17720  517.993103   True
#
# [9391 rows x 4 columns]

# %%
def no_DN (frame):
    data = []

    i = frame.index[0][0]
    a = 0
    for j in range(0,len(frame.loc[i])): 
        if frame.loc[i, 'isDN'].loc[j] == False and frame.loc[i, 'hitTime'].loc[j] < 300:
            a += 1
    for j in range(0,len(frame.loc[i])): 
        if frame.loc[i, 'isDN'].loc[j] == False and frame.loc[i, 'hitTime'].loc[j] < 300:
            data.append({'nHits': a,
                       'pmtID': frame.loc[i, 'pmtID'].loc[j],
                       'hitTime': frame.loc[i, 'hitTime'].loc[j] })
            
    frame_noDN = pd.DataFrame(data)
    return frame_noDN

# %%
ev7667_noDN = no_DN(ev7667)
ev7667_noDN
# Out:
#       nHits  pmtID     hitTime
# 0      8465  17091   48.687401
# 1      8465  16670   44.291088
# 2      8465  14771   29.709875
# 3      8465  15986   72.263649
# 4      8465  15579   48.973534
# ...     ...    ...         ...
# 8460   8465  12168  104.834717
# 8461   8465  13385   46.464973
# 8462   8465  16866   27.218077
# 8463   8465  16007   74.224442
# 8464   8465  14158   42.322063
#
# [8465 rows x 3 columns]

# %%
PMT_pos = datafile["lpmt_pos"]
PMT_pos_pd = PMT_pos.pandas.df()
PMT_pos_pd
# Out:
#        pmt_id         pmt_x        pmt_y         pmt_z
# entry
# 0           0  1.049021e+03     0.000000  19171.320312
# 1           1  9.084785e+02   524.510315  19171.320312
# 2           2  5.245103e+02   908.478516  19171.320312
# 3           3  6.423399e-14  1049.020630  19171.320312
# 4           4 -5.245103e+02   908.478516  19171.320312
# ...       ...           ...          ...           ...
# 17734   17734  1.904750e+04 -2395.499268   -307.276520
# 17735   17735  1.910673e+04 -1865.088745   -307.276520
# 17736   17736  1.915119e+04 -1333.236816   -307.276520
# 17737   17737  1.918085e+04  -800.354553   -307.276520
# 17738   17738  1.919569e+04  -266.853577   -307.276520
#
# [17739 rows x 4 columns]

# %%
def new_spherical (xyz):
    data = []
    for i in range(0, len(xyz)):
        r = np.sqrt(xyz.loc[i, 'pmt_x']**2 + xyz.loc[0,'pmt_y']**2 + xyz.loc[i, 'pmt_z']**2)
        theta = np.arccos((xyz.loc[i, 'pmt_z'])/r)
        if xyz.loc[i, 'pmt_x'] == 0 and xyz.loc[i, 'pmt_y'] > 0:
            phi = np.pi/2
        if xyz.loc[i, 'pmt_x'] == 0 and xyz.loc[i, 'pmt_y'] > 0:
            phi = 3*np.pi/2
        if (xyz.loc[i, 'pmt_x'] > 0 and xyz.loc[i, 'pmt_y'] >= 0):
             phi = np.arctan((xyz.loc[i, 'pmt_y'])/(xyz.loc[i, 'pmt_x']))
        if (xyz.loc[i, 'pmt_x'] > 0 and xyz.loc[i, 'pmt_y'] <= 0):
             phi = np.arctan((xyz.loc[i, 'pmt_y'])/(xyz.loc[i, 'pmt_x'])) +2*np.pi
        elif (xyz.loc[i, 'pmt_x'] < 0 and xyz.loc[i, 'pmt_y'] > 0) or (xyz.loc[i, 'pmt_x'] < 0 and xyz.loc[i, 'pmt_y'] < 0):
            phi = np.arctan((xyz.loc[i, 'pmt_y'])/(xyz.loc[i, 'pmt_x'])) + np.pi
        data.append({'pmt_id': i,
                    'pmt_r': r,
                    'pmt_theta': theta,
                    'pmt_phi': phi })
    rtp = pd.DataFrame(data)
    return rtp

# %%
PMT_spher_pd = new_spherical(PMT_pos_pd)
PMT_spher_pd
# Out:
#        pmt_id         pmt_r  pmt_theta   pmt_phi
# 0           0  19199.999136   0.054664  6.283185
# 1           1  19192.833447   0.047352  0.523599
# 2           2  19178.494039   0.027352  1.047198
# 3           3  19171.320312   0.000000  1.570796
# 4           4  19178.494039   0.027352  2.094395
# ...       ...           ...        ...       ...
# 17734   17734  19049.976396   1.586927  6.158078
# 17735   17735  19109.197230   1.586877  6.185879
# 17736   17736  19153.654386   1.586840  6.213681
# 17737   17737  19183.310731   1.586815  6.241483
# 17738   17738  19198.144766   1.586803  6.269284
#
# [17739 rows x 4 columns]

# %%
def normal_ft(ev):
    data = []
    ma = ev.loc[:, 'hitTime'].max()
    mi = ev.loc[:, 'hitTime'].min()
    mami = ma - mi
    for i in range(0, len(ev)):
        a = ev.loc[i, 'nHits']
        b = ev.loc[i, 'pmtID']
        c = (ev.loc[i, 'hitTime'] - mi)/mami
        data.append({'nHits': a, 'pmtID': b, 'hitTime': c})
        
    norm = pd.DataFrame(data)
    return norm

# %%
ev7667_norm = normal_ft(ev7667_noDN)
ev7667_norm
# Out:
#       nHits  pmtID   hitTime
# 0      8465  17091  0.110772
# 1      8465  16670  0.095193
# 2      8465  14771  0.043521
# 3      8465  15986  0.194319
# 4      8465  15579  0.111786
# ...     ...    ...       ...
# 8460   8465  12168  0.309742
# 8461   8465  13385  0.102896
# 8462   8465  16866  0.034691
# 8463   8465  16007  0.201268
# 8464   8465  14158  0.088215
#
# [8465 rows x 3 columns]

# %%
time7667 = ev7667_norm.loc[:, 'hitTime']
plt.hist(time7667, bins=20, ec='black', color='green')
plt.show()

# %%
def ev_mollweide (ev_map):
    # Set the coordinates for the input
    nside = 16
    npix = hp.nside2npix(nside)

    # Coordinates and the density field f
    thetas = PMT_spher_pd.loc[:, 'pmt_theta']
    phis = PMT_spher_pd.loc[:, 'pmt_phi']
    hitTime = ev_map.loc[:, 'hitTime']

    # Go from HEALPix coordinates to indices
    indices = hp.ang2pix(nside, thetas, phis)

    # Initate the map and fill it with the values
    hpxmap = np.zeros(npix, dtype=np.float)
    for i in range(len(ev_map)):
        hpxmap[indices[ev_map.loc[:, 'pmtID'].loc[i]]]  = hitTime.loc[i]
   # for j in range(len(hpxmap)):
   #     if hpxmap[j] == 0:
   #         hpxmap[j] = 1024
        
    # Inspect the map
    hp.mollview(hpxmap)

# %%
ev_mollweide(ev7667_norm)
